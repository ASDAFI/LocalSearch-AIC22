# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="XB Niloofar" size=5>
# 				<p></p>
# 				<p></p>
#                     «به نام خدا»
# 				<p></p>
# 			</font>
#           </div>
# 		<hr/>
# 		<font color=#029C8B size=6>
# 			<br />
# 			<div align=center>
#                محتوای علمی نبرد هوش مصنوعی
#             </div>
# 		</font>
#         <font color=#E7234D size=6>
# 			<br />
# 			<div align=center>
#                  «Local Search»
#             </div>
# 		</font>
# 		<br />
# 		<div align=center>
#             علی صدفی
#         </div>
# 		<hr />
# 		<style type="text/css" scoped>
#             p{
#                 border: 1px solid #a2a9b1;background-color: #f8f9fa;display: inline-block;
#             };
#         </style>
# 		<div>
# 			<h3>فهرست مطالب</h3>
# 			<ul style="margin-right: 0;">
#                 <li>
# 					<a href="#INTRO">
#                         مقدمه
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#GREEDY">
#                         حریصانه
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#KNAPSACK">
#                         کوله‌پشتی
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#KNAPSACKGREEDY">
#                         رویکرد حریصانه
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#MODELING">
#                          مدل سازی
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#BRUTEFORCE">
#                     بررسی حالات
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#LC">
#                     Local Search
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#CONNECTIVITY">
#                     اتصال
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#LOCALMINIMA">
#                     local Minima
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#REF">
#                     منابع
#                     </a>
# 				</li>
#         </div>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="INTRO" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             فضای مساله بزرگ است!
#         </font>
#         <p></p>
# تا به حال، فضاهایی را مشاهده‌ کردیم که قابل گشت بودند. می‌توانستیم همه چیز را در آن بررسی کنیم، حالت‌های مختلف را دریابیم و به کمک ایده‌هایی این بررسی را کمی کوتاه تر کنیم. می‌دانستیم که جواب ما قطعی است و می‌توانستیم این امر را ثابت کنیم. آیا در همه مسئله‌ها این امکان وجود دارد؟ در بازی شطرنج یا جاهایی که اوضاع پیچیده‌تر است هم این اتفاق ممکن است؟
#
# جوابی که می‌توان داد به وضوح خیر است! در بسیاری از مسئله‌ها، فضای مسئله بسیار بزرگ است، بدین معنا که بررسی تمامِ آن هزینه بسیار زیادی دارد. هزینه‌ای اعم از زمان، حافظه و … که واقعا کاستن آن دارای پیچیدگیست.
#
# در دنیای امروز که ما با داده‌های کلان رو در رو هستیم، تعداد حالت‌های مسئله ما بسیار زیاد است، به قدری که بررسی همه حالت‌ها، یا حتی بیشتر آن آرزویی بیش نیست:)
#
# چالشی که امروز علوم کامپیوتر را درگیر کرده است، حل همین مسئله‌ها می‌باشد. اگر نمی‌شود تمام حالات را بررسی کرد، راهی وجود دارد که بدون بررسی همه یا بیشترِ حالات به بهترین جواب رسید؟
#
# بیایید تا با بررسی مساله‌ای ساده کار خود را آغاز کنیم. پس بزن بریم:)
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             گنج بزرگ
#         </font>
#         <p></p>
# گنج فراعنه، در جایی زیر همین اهرام‌ها نفهته است. شما قصد بر سفر به مصر می‌کنید، سختی های بیابان را می‌پیمایید و به اهرام می‌رسید. پس از عبور از تله‌ها، بالاخره گنج بزرگ را می‌یابید:)
# اتاقی مملو از زر و سیم رو به روی شماست. زمانی که برق طلا‌ها چشمان شما را گرفته است، یکی از تله‌های محافظ گنج فعال می‌شود. گنج در حال فرو رفتن به قعر زمین است! حال باید عجله کنید!
#
# <img src='images/treasure.jpg' style="width:50%;height:50%;">
#
# شما یک زمان کوتاهی فرصت دارید تا کوله‌پشتی خود را پر کنید. اگر عجله نکنید شما هم همراه این گنج دفن خواهید شد!
# چیزی که می‌دانیم، این است که شما سراغ با ارزش ترین اشیا خواهید رفت. شما قطعا سکه‌های طلا را به سکه‌های نقره ترجیح خواهید داد.
#
# اگر فرض کنیم اقلام مختلف وزن و حجمی ندارند، یعنی بدون احساس سنگینی خاصی می‌توانید آن ها را درون کوله قرار دهید، شما از گران‌ترین وسیله شروع خواهید کرد. زیرا به این روش در این زمان کوتاه بیشترین سود را می‌کنید.
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="GREDDY" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             حریصانه
#         </font>
#         <p></p>
# مشخص است که اگر از شما بخواهند میان تعدادی جایزه یک جایزه را انتخاب کنید، با ارزش‌ترین آن ها را برای خود انتخاب می‌کنید.
#
# ایده‌ای که می‌بینید، یکی از ساده ترین رویکرد‌ها در حل مسئله‌ است.
#
# در این ایده شما کاری را می‌کنید که در این لحظه بیشترین سود را ببرید.
#
# مثلا وقتی تعدادی اسکناس روی زمین است و به شما می‌گویند که می‌توانید ۱۰ اسکناس به انتخاب خود از روی زمین بردارید، شما در هر مرحله با ارزش‌ترین اسکناس را برخواهید داشت.
#
# با این روش، شما حریصانه عمل خواهید کرد و در هر مرحله انتخابی می‌کنید که بیشترین سود لحظه‌ای را ببرید.
#
# باید دقت کنید که بیشترین سود در هر لحظه، لزوما بیشترین سود را در آخر به شما نخواهد داد مگر اینکه این موضوع را بتوانید ثابت کنید.
#
# بیایید تا راه حل حریصانه خود را برای مسئله اسکناس‌ها بررسی کنیم.
#
# از برهان خلف استفاده می‌کنیم. فرض کنیم که از این روش استفاده کردیم و به ترتیب با ارزش ترین اسکناس‌ها را از روی زمین برداشتیم و طبق فرض این بهترین حالت نیست و حالتی وجود دارد که اسکناس‌های جمع‌آوری شده با ارزش تر است.
# می‌دانیم که این دو جواب متفاوت هستند، در نتیجه در تعدادی از اسکناس ها تفاوت دارند، بدین معنا که ما برای این‌که به بهترین جواب برسیم باید تعدادی اسکناس را بر روی زمین قرار دهیم و تعدادی اسکناس جدید از روی زمین برداریم.
# ما می‌دانیم که هر اسکناسی که اکنون در دست داریم با ارزش تر از همه اسکناس های روی زمین است یا نهایتا با ارزش ترین
# اسکناس روی زمین هم ارزش است.
#
# در نتیجه اگر یک اسکناس را از دست خود به روی زمین بگذاریم و اسکناسی جدید برداریم، حداکثر ۰ واحد به ارزش اسکناس های درون دست ما اضافه خواهد شد. حال اگر $n$ اسکناس را از دست خود روی زمین قرار دهیم و $n$ اسکناس دیگر را از روی زمین برداریم، حداکثر $0 \times n$ واحد یعنی ۰ واحد به ارزش اسکناس های درون دست ما اضافه خواهد شد.
# در نتیجه راه حل جدید که راه حلی متفاوت است، از راه حل ما بهتر نیست. تناقضی که در اینجا به آن برخورد می‌کنیم این موضوع را ثابت می‌کند.
#
# در اینجا ما راه حل حریصانه را برای اسکناس ها بررسی کردیم و ثابت کردیم این الگوریتم در هر مرحله علاوه بر انتخاب بهترین گزینه لحظه‌ای، بهترین گزینه را برای کل مسئله انتخاب می‌کند.
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             کمی کد!
#         </font>
#         <p></p>
# حال بیایید برای دست‌گرمی کمی تمرین کنیم.
#
# ما در اینجا pseudo code الگوریتم حریصانه را بررسی خواهیم کرد و تمرینی بر آن خواهیم داشت.
#
# pseudo code (سودو کد خوانده می‌شود!) زبانیست متفاوت از تمام زبان‌های برنامه‌نویسی که درک و فهم آن برای انسان بسیار ساده‌تر است.
# برنامه‌نویسی به کمک سودو کد ها بسیار راحت می‌باشد زیرا بسیار خوانا است و درک آن ها نیاز به علم به زبان برنامه‌نویسی خاصی ندارد. می‌توان گفت سودو کد زبان مشترک میان تمام برنامه‌نویس هاست.
#
# با سودو کد الگوریتم حریصانه آغاز می‌کنیم:
#
# <img src='images/greedy-pseudo code.png' style="width:50%;height:50%;">
#
#
# بیایید تا خط به خط جلو برویم:
#
# 1- ما باید مجموعه ای از انتخاب ها داشته باشیم که جواب مساله ما است.
#  ما مجموعه جواب $S$ را برابر تهی قرار می‌دهیم.
#
# 2- در مرحله بعد به ازای تمام انتخاب‌ها، هزینه انتخاب را حساب می‌کنیم. اصطلاح هزینه همیشه اصطلاحی منفی بوده است و ما به دنبال کمینه کردن مقدار آن هستیم. در مساله ما بحث ارزش وجود دارد که ما می‌خواهیم آن را بیشینه کنیم.
#
# 3- حالا تا زمانی که $S$ یک راه حل ممکن و کامل نشده است باید کار‌هایی را انجام دهیم. منظور از ممکن و کامل بودن این است که $S$ به عنوان یک جواب مساله قلمداد شود. در مورد مساله اسکناس ها می‌توانیم بگوییم که $S$ باید حاوی $n$ عضو باشد زیرا ما باید $n$ اسکناس انتخاب کنیم.
#
# 4- حال در هر مرحله از اجرای این حلقه ما باید انتخاب $s$ را از مجموعه انتخاب های $E$ پیدا کنیم که کمترین هزینه را برای ما دارد. در مساله اسکناس ها ما باید مساله را برای ارزش ها حل کنیم درنتیجه باید انتخابی را برگزینیم که بیشترین ارزش را داشته باشد. بیشترین ارزش معادل با کم‌ترین هزینه می‌تواند باشد.
#
# 5- حال انتخاب خود $s$ را به مجموعه انتخاب ها $S$ اضافه می‌کنیم.
#
# 6- حالا باید $s$ را از مجموعه همه انتخاب‌ها یعنی $E$ حذف کنیم. در مرحله بعد نیز مقدار هزینه جدید (یا ارزش جدید) را برای هر انتخاب $e$ که در $E$ واقع است می‌یابیم.
# در آخر می‌دانیم که $S$ پاسخ حریصانه ما به مساله است.
#
#
# اگر بخواهیم الگوریتم حریصانه را جمع‌بندی کنیم، شما باید در هر مرحله حریصانه عمل کنید و فقط به فکر این لحظه خود ( یا لحظات محدودی) باشید. شما باید بر اساس انتخاب های محدود، بهترین انتخاب خود را بکنید.
#
# همانطور که گفتیم این راه حل لزوما بهترین جواب ممکن را به شما نمی‌دهد، زیرا آخر عاقبت طمع لزوما خوش نیست:)
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             تمرین
#         </font>
#         <p></p>
# با حل تمرینات زیر درک بهتری نسبت به الگوریتم های حریصانه پیدا خواهید کرد:)
#
# <a href="https://codeforces.com/problemset/problem/231/A">1) Codeforces - Team</a>
#
# <a href="https://quera.org/problemset/51866/">2) کافه کیک - Quera</a>
#
# <a href="https://quera.org/problemset/3031/">3) انرژی خور - Quera </a>
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="KNAPSACK" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             کوله‌پشتی
#         </font>
#         <p></p>
# مسئله کوله‌پشتی از معروف‌ترین مساله‌های علوم کامپیوتر است. در این مساله شما کوله پشتی‌ای به گنجایش $k$ دارید. همچنین $n$ کالا(شی) اطراف شما حضور دارد که هر کالا دارای وزن $w_i$ و ارزش $v_i$ می‌باشد. شما باید بهترین کوله‌پشتی ممکن را جمع آوری کنید. (با ارزش‌ترین کوله‌پشتی ای که جمع‌آوری آن امکان‌پذیر است. شرط امکان پذیری به دلیل محدودیت در گنجایش کوله‌پشتی است. در نتیجه باید به وزن کالا ها و گنجایش کوله‌پشتی دقت کرد!) خروجی شما در این مساله دنباله ای از $0$ و $1$ ها می‌باشد که عدد $i$ ام بیانگر بودن یا نبودن کالای $i$ ام در کوله‌پشتی است. ($0$ بیانگر عدم وجود و $1$ بیانگر وجود کالا است.)
#
# <img src='images/knapsack.png' style="width:50%;height:50%;">
#
#
# از این مساله به عنوان knapsack 0-1 یاد می‌شود. مساله های دیگری نیز وجود دارند، مثلا مساله ای که فقط ارزش بیشترین کوله‌پشتی را می‌خواهد،  مساله ای که محدودیت حجم هم در آن وجود دارد یا مساله ای که در آن می‌توان کالا ها را شکست و به بخش های کوچک‌تر تقسیم کرد.
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             آماده‌سازی
#         </font>
#         <p></p>
# قطعه کد زیر را اجرا کنید تا برای ادامه مسیر آماده شویم:)
#     </font>
# </div>

# %%
from knapsack.problem import *

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             نمونه‌ها
#         </font>
#         <p></p>
# ما برای این مساله تعدادی نمونه (sample) آماده کرده‌ایم. بیایید تا با نحوه کار با نمونه‌ها آشنا شویم.
# نمونه‌ها بر اساس تعداد کالا یا همان $n$ تقسیم بندی شده اند. برای اینکه بفهمیم که چند نمونه داریم و این نمونه‌ها چه $n$ هایی را شامل می‌‌شوند از قطعه کد زیر استفاده می‌کنیم:
#     </font>
# </div>

# %%
get_cases()

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
# برای مشاهده هر نمونه، ابتدا باید قالب نمونه را درک کنیم. می‌دانیم که $n$ کالا داریم و گنجایش کوله‌پشتی $k$ هست. کالای $i$ ام دارای ارزش  $v_i$ و وزن $w_i$ می‌باشد.
#
# فرمت ورودی بدین نحو است:
#
# $$
# n \ \ k \\
# v_1 \ \ w_1 \\
# v_2 \ \ w_2 \\
# v_3 \ \ w_3 \\
# \dots \\
# v_n \ \ w_n
# $$
#
# همینطور که می‌بینید در خط اول $n$ و$k$ به ترتیب از چپ به راست نمایش داده می‌شوند.
#
# سپس در $n$ خط بعدی در هر خط، ورودی مربوط به یک کالا وجود دارد.
#
# خط $i$ ام به ترتیب از چپ به راست نمایشگر $v_i$ که ارزش کالای $i$ ام است و $w_i$ که وزن کالای $i$ ام است می‌باشد.
#
# با استفاده از قطعه کد زیر می‌توانید نمونه مورد نظر خود را روی صفحه چاپ کنید. این تابع عدد صحیح $n$ را به عنوان ورودی دریافت می‌کند که نمونه شما با آن مقدار $n$ است.
#
# نکته: برای هر $n$ یک نمونه وجود دارد.
#
# تذکر: برای $n$ می‌توانید از نمونه‌های موجود ورودی انتخاب کنید. بدست آوردن نمونه‌های موجود را در بخش قبل بررسی کردیم.
#     </font>
# </div>

# %%
show_input(4)

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
#     حال برای راحتی کار ما تابعی وجود دارد که ورودی ها را به حالت قابل استفاده در می‌اورد.
#
# این تابع عدد صحیح $n$ را که نمونه شما است دریافت می‌کند به ترتیب $n$ ، $k$ و $V$ ، $W$ را خروجی می‌دهد.
# $W$ مجموعه وزن‌ها و $V$ مجموعه ارزش ها است. $V[i]$ به ارزش کالای $i$ ام و $W[i]$ به وزن کالای $i$ ام اشاره دارد.
#
# نمونه کد استفاده از تابع برای $n=4$ :
#     </font>
# </div>

# %%
n, k, V, W = get_input(4)

# %% [markdown]
# <p></p>
# <br />
# <div id="KNAPSACKGREEDY" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             رویکرد حریصانه
#         </font>
#         <p></p>
# قبل از شروع بیایید تا خودمان را در شرایط بسنجیم. ما می‌خواهیم خود را در شرایط نمونه‌ی $n=7$ قرار دهیم.
#
# ابتدا ورودی ها را روی صفحه چاپ می‌کنیم:
#     </font>
# </div>

# %%
show_input(7)

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         <p></p>
# شما در اهرام مصر قرار دارید. اگر بخواهیم این اعداد را شبیه‌سازی کنیم تا ماجرا را بهتر درک کنید، شکل زیر را داریم:
#
# <img src='images/knapsack-7-sample.jpg' style="width:50%;height:50%;">
#
# حالا تایمر خود را فعال کنید! شما یک دقیقه فرصت دارید تا بهترین کوله‌پشتی را برای خود جمع کنید. تلاش کنید که کوله‌پشتی خوبی جمع‌آوری کنید. حواستان باشد که بیشتر از یک دقیقه نشود زیرا چند میلیون دلار ارزش جانتان را ندارد!)
#
# جواب خود را درجایی بنویسید و ارزش آن را نیز یادداشت کنید.
#
#
# حالا بیایید تا مساله را با رویکرد حریصانه بررسی کنیم. هدف ما بیشینه کردن ارزش کوله پشتی است. بهترین تصمیمی که می‌توانیم برای این لحظه بگیریم، این است که با ارزش ترین کالایی که در کوله‌پشتی جا می‌شود را انتخاب کنیم.
#
# بیایید تا این راه حل را پیاده کنیم! برای راحتی شما تابعی ساخته شده است تا کالا ها را بر حسب ارزش مرتب کند. این تابع $n$ و $V$ را به ترتیب به عنوان ورودی دریافت می‌کند و سپس کالا ها را بر اساس ارزش مرتب می‌کند.
# خروجی تابع مجموعه $I$ است.
#
# این مجموعه شامل اعداد $0$ تا $n$ می‌باشد (خود $n$ را شامل نیست.). این مجموعه به ترتیب شماره با ارزش ترین کالا ها را نمایش می‌دهد.
#
# $I[0]$ شماره‌ی با ارزش‌ترین کالا ($i$ آن کالا) در میان کالا ها است.
#
# نمونه استفاده از این مرتب سازی به کمک نمونه ‌$n = 4$ :
#     </font>
# </div>

# %%
n, k, V, W = get_input(4)
I = sort_by_values(n, V)

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
# پس از مرتب سازی مساله ما بدین شکل خواهد شد و کالا ها به ترتیب ارزش قرار خواهند گرفت:
# <img src='images/knapsack-7-sample-sortbyvalue.jpg' style="width:50%;height:50%;">
#
#
# حالا شما باید راه حل حریصانه خود را پیاده سازی کنید. شما تابعی دارید که به ترتیب $n$ ،  $k$ ، $V$ و $W$ را دریافت می‌کند.
#
# خروجی تابع شما لیستی از یک ها و صفر هاست، که عدد $i$ ام به موجودیت کالای $i$ اشاره دارد.
#
# این تابع را به عنوان نمونه ما تکمیل می‌کنیم اما بدانید که جلوتر باید دست به کد شوید!
#     </font>
# </div>

# %%
def do_greedy_by_values(n, k, V, W):
    # this function does greedy by values
    
    answer = [0] * n
    current_capacity = k
    
    I = sort_by_values(n, V)
    
    for i in I:
        if current_capacity >= W[i]:
            answer[i] = 1
            current_capacity -= W[i]
    
    return answer

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
# برای تست تابع شما، تابعی ساخته شده است که به شما کمک می‌کند.
#
# این تابع ارزش کوله‌پشتی شما و کالا‌های موجود در آن را به صورت صفر و یک روی صفحه چاپ می‌کند.
#
# ورودی تابع $n$ که عدد صحیح نمایانگر نمونه است و $\text{solver}$ که تابع شماست می‌باشد.
#
# نمونه استفاده تابع بالا برای $n=7$ :
#     </font>
# </div>

# %%
test_solver(7, do_greedy_by_values)

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
# می‌بینیم که الگوریتم ما کوله پشتی‌ای با ارزش 14 تولید می‌کند.
#
# این هم نمونه‌ی ما برای $n=7$ که می‌توانید ببینید:)
#
#
# آیا این بهترین کوله‌پشتی ای است که وجود دارد؟ بیایید تا بررسی کنیم.
#
# آیا ایده حریصانه دیگری برای این مساله وجود دارد؟ بله! ایده های دیگری ام وجود دارند. می‌توانید الگوریتم حریصانه خود را بر مبنای وزن کالا ها قرار دهید. به این معنا که به کالا با وزن کمتر اولویت بیشتری بدهید.
#
# هر دو راه حل حریصانه ما یک بعد از مساله را حذف می‌کند. مساله ما به هر دو پارامتر وزن و ارزش وابسته است.
#
# ایده‌ای که ممکن است به ذهنتان برسد چگالی است! شما می‌توانید پارامتری جدید به نام چگالی خلق کنید که چگالی کالای $i$ ام به صورت زیر تعریف می‌شود:
# $$d_i = \frac{v_i} {w_i}$$
#
# این مقدار چگالی یا همان $\text{density}$ کالای  $i$ ام می‌باشد.
#
# این مقدار بیانگر میزان ارزشی است که به ازای هر یک واحد از وزن کالا کسب می‌کنیم. در این معیار، هر دوی وزن و ارزش دخیل هستند.
#
# و باز هم برای راحتی شما:) تابعی برای مرتب سازی کالا‌ها بر حسب چگالی وجود دارد. خروجی این کالا همانند خروجی مرتب‌سازی بر حسب ارزش می‌باشد.
# ورودی های این تابع نیز به ترتیب $n$ ، $V$ ، $W$ می‌باشد.
#
# نمونه استفاده تابع برای ورودی $n=7$ :
#     </font>
# </div>

# %%
n, k, V, W = get_input(7)
I = sort_by_density(n, V, W)

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
#
# پس از مرتب سازی مساله ما بدین شکل خواهد شد و کالا ها به ترتیب ارزش قرار خواهند گرفت:
#
# <img src='images/knapsack-7-sample-sortbydensity.jpg' style="width:50%;height:50%;">
#
#
# همانند قسمت قبل به تابعی نیاز داریم تا مساله را حل کند با این تفاوت که رویکرد حریصانه ما تغییر کرده است.
#
# شما تابعی دارید که به ترتیب $n$ ،  $k$ ، $V$ و $W$ را دریافت می‌کند.
#
# خروجی تابع شما لیستی از یک ها و صفر هاست، که عدد $i$ ام به موجودیت کالای $i$ اشاره دارد.
#
# پیاده‌سازی این رویکرد حریصانه بسیار شبیه رویکرد قبلی است.
#     </font>
# </div>

# %%
def do_greedy_by_density(n, k, V, W):
    # this function does greedy by densities
    answer = [0] * n
    current_capacity = k
    
    I = sort_by_density(n, V, W)
    
    for i in I:
        if current_capacity >= W[i]:
            answer[i] = 1
            current_capacity -= W[i]
    
    return answer

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
#  حالا بیایید تا راه حل خود را تست کنیم تا ببینیم اینجا به ازای $n=7$ چه خروجی‌ای خواهد داد.
#     </font>
# </div>

# %%
test_solver(7, do_greedy_by_density)

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
# توانستیم کوله‌ای به ارزش 18 بسازیم:) فهمیدیم که راه حل حریصانه قبلی ما لزوما بهترین جواب را نمی‌دهد.
# آیا این جواب ما بهترین جواب است؟
#
# بیایید کوله‌‌ پشتیِ زیر را بچینیم:
#
# <img src='images/knapsack-7-sample-bestanswer.jpg' style="width:50%;height:50%;">
#
# همانطور که دیدید بله! ارزش این کوله‌پشتی 20 است! یعنی هر دو راه حل حریصانه ما از رسیدن به بیشتری جواب عاجز ماندند.
# گفته بودیم که راه‌حل حریصانه، لزوما ما را به سمت بهترین جواب هدایت نمی‌کند.
#
# حالا چطوری می‌توان بهترین کوله‌پشتی را جمع کرد؟
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="MODELLING" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             مدل سازی
#         </font>
#         <p></p>
# تا اینجای کار با دید کاملا شهودی به ماجرا جلو رفتیم. اما این روش حل مساله ما لزوما درست است؟ اتفاقی که خوب است قبل از حل مساله بی‌افتد مدل سازی مساله است.
#
# باید بتوانیم دقیقا مشخص کنیم که مساله چه می‌خواهد و به دنبال چه هستیم.
#
# بیایید تا با یک مسئله خیلی سخت به نام آلبالو کار را شروع کنیم:)
#
# آلبالو های علی با شش برابر آلبالو های محمد برابر است. اگر مجموع آلبالو‌های این دو فرد 14 باشد، هر کدام از آن ها چند آلبالو دارد؟
#
# <img src='images/cherry.jpg' style="width:50%;height:50%;">
#
#
#
# در این مساله چیزی که ما به دنبال آن هستیم تعداد آلبالوهای این دو نفر است. بیایید تا به زبان ریاضی مساله را مدل سازی کنیم.
# کاری که ما در این موارد می‌کنیم، تشکیل معادله است. این مدل سازی ریاضی به ما می‌فماند که دقیقا به دنبال چه هستیم.
#
#
# اگر علی $a$ البالو و محمد $b$ آلبالو داشته باشد، داریم:
# $$ a = b \times 6 \ \ \ \land \ \ \  a + b = 14 $$
#
# نماد $\land$ همان عملگر "و" (AND) منطقی است. به این معنا که هر دو گزاره صحیح هستند.
#
# هدف ما یافتن $a$ و $b$ ای است که جواب مساله باشند. ما در اینجا جواب مساله را به طور دقیق‌تر توانستیم تعریف کنیم. منظور از جواب مساله بودن، $a$ و $b$ ای است که شرط بالا به ازایش صدق کند.
#
# این یک ‌نمونه از مدل سازی مساله است. مساله های بسیار زیادی اعم از آلبالو، گیلاس و … :) می‌توانند به این نحو مدل شوند.
# خیلی اوقات ما بدون این‌که بدانیم از این مدل سازی ها برای راحت‌تر شدن کار خود استفاده می‌کنیم.
#
# این مدل‌سازی ها به ما کمک می‌کند تا متوجه شویم که دقیقا چه می‌خواهیم. این اتفاق ما را به رسیدن به جواب نزدیک‌تر می‌کند.
#
# حال بیایید تا مساله خود را مدل‌سازی کنیم!)
#
# در این مساله ما $n$ کالا  (شی) داریم که هر کالا ارزش $v_i$ را دارد. می‌دانیم که هر کالا در کوله‌پشتی وجود دارد یا وجود ندارد که می‌توانیم این ویژگی را با $x_i$ به نمایش بگذاریم. این مقدار همواره $0$ یا ‌$1$ می‌باشد. این امر را می‌توانیم به شکل زیر بیان کنیم:
# $$x_{i}\in \{0,1\}$$
#
# می‌دانیم که ارزش ذاتی و وزن ذاتی هر کالا، همان وزن و ارزش آن است که به خود کالا برمی‌گردد. انتخاب کردن یا نکردن آن کالا تاثیری در ارزش و وزن ذاتی آن ندارد.
#
#
# حالا بیایید تا مفهوم ارزش حقیقی و وزن حقیقی هر کالا را برای خود تعریف کنیم.
# ما می‌دانیم که اگر کالایی در کوله‌پشتی نباشد، ارزش و وزنی برای ما نخواهد داشت. در نتیجه نه هزینه (وزن) و نه سود (ارزش) ای از آن ما را شامل می‌شود.
# ارزش حقیقی و وزن حقیقی کالاهایی که در کوله‌پشتی نیستند را می‌توانیم $0$ در نظر بگیریم.
#
# می‌دانیم ارزش حقیقی ای که هر کالا برای ما دارد $x_i \times v_i$ می‌باشد. چرا؟ به این علت که اگر کالا در کوله‌پشتی باشد $x_i$ برابر با $1$ است در نتیجه  $x_i \times v_i$ برابر $v_i$ می‌شود. پس این کالا برای ما $v_i$ ارزش دارد. حالا اگر این کالا در کوله‌پشتی نباشد، $x_i$ برابر با $0$ است در نتیجه  $x_i \times v_i$ برابر $0$ می‌شود. پس این کالا برای ما هیچ ارزشی ندارد. مهم نیست که ارزش ذاتی کالا چقدر است، اگر کالا درون کوله‌پشتی نباشد هیچ ارزشی برای ما ندارد (ارزش حقیقی آن $0$ است.).
#
# با این اوصاف می‌توانیم بیان کنیم که ارزش کوله‌پشتی جمع‌آوری شده، برابر مجموع ارزش های حقیقی است. زیر در نظر گرفتیم که اگر کالا در کوله‌پشتی نباشد ارزش ذاتی آن بی‌اهمیت است و ارزش حقیقی آن $0$ می‌باشد. اعلام کردیم که اگر کالا درون کوله‌پشتی باشد ارزش حقیقی آن $v_i$ می‌شود.
#
# همین موضوع برای وزن نیز صدق می‌کند. وزن کوله‌پشتی جمع‌آوری شده توسط ما، بنا به استدلال قبلی این بار برای وزن،‌برابر مجموع وزن حقیقی تمام کالا هاست.
#
# در نتیجه می‌توانیم وزن و ارزش کوله‌پشتی جمع‌آوری شده را به صورت زیر بنویسیم:
#
# $$ \text{Total value}= \sum_{i=1}^{n}v_i \times x_i$$
# $$ \text{Total weight} = \sum_{i=1}^{n}w_i \times x_i$$
#
# هدفی که ما داریم بیشینه کردن ارزش کوله‌پشتی است. همزمان باید حواسمان به وزن کوله‌پشتی جمع آوری شده باشد تا از محدودیت گذر نکند. می‌توانیم مدل مساله را به صورت زیر بنویسیم:
#
# $$ \text{maximize}  \sum_{i=1}^{n}v_i \times x_i  \ \ \ \ \ \ \text{s.t} \ \ \ \ \ \ \  \sum_{i=1}^{n}w_i \times x_i \leqslant k$$
# $$x_{i}\in \{0,1\}$$
#
# این عبارت بیانگر این مورد است که ما می‌خواهیم ارزش کوله‌پشتی را بیشینه کنیم به نحوی که ($\text{s.t}$) وزن کوله‌پشتی جمع‌شده از محدودیت وزن کوله‌پشتی گذر نکند.
#
# ما به دنبال $X$ ای هستیم که $\lvert X \rvert = n$ (تعداد اعضای آن برابر n باشد.) و $x_i \in X \Rightarrow x_i \in \{0,1\}$ (همه اعضای آن صفر یا یک باشند.).
#
# $X$ همان جواب مساله ما و خروجی تابع ما می‌باشد.
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="BRUTEFORCE" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             بررسی همه حالات
#         </font>
#         <p></p>
# ساده‌ترین ایده‌ای که برای حل این مساله می‌تواند به ذهن همه برسد، بررسی همه حالات است. در این راه حل ما همه جواب های ممکن را بررسی می‌کنیم و بهترین جواب را خروجی می‌دهیم.
#
# این راه حل مانند روش حریصانه نخواهد بود و به وضوح بهترین جواب را به ما خروجی خواهد داد.
#
# می‌دانیم به ازای هر $X$ با شرط‌های ذکر شده، یک جواب برای مساله خود داریم. ما باید تمام $X$ های موجود را بررسی کنیم و ببینیم که کدام موردِ ممکن،  دارای بیشترین ارزش است.
#
# می‌دانیم که $X$ دارای $n$ عضو است که هر عضو آن را $0$ یا $1$ تشکیل می‌دهد. در نتیجه هر عضو $X$ دارای دو حالت است پس (بنا به اصل ضرب!) ما $2^n$ مقدار $X$ متمایز داریم.
#
# حال برای بررسی همه این حالات باید ایده‌ای داشته باشیم. باید بتوانیم حالت‌های جدید را تولید کنیم.
#
# یکی از ایده های ساده‌ای که وجود دارد، کمک گرفتن از اعداد در مبنای دو است. اگر جواب $X$ را داشته باشیم که $X = \{x_1, x_2, x_3, \dots\, x_n\}$ می‌توانیم عدد $B$ را این‌گونه تعریف کنیم:
# $$B = x_1 x_2 x_3 \dots x_n$$
# عدد $B$ شامل ارقام 0 و 1 است، در نتیجه این عدد در مبنای دو می‌باشد.
#
# می‌توانیم نتیجه بگیریم که به ازای هر $X$ یک عدد $B$ که در مبنای دو است وجود دارد.
#
# می‌دانیم که $B$ دارای $n$ رقم است، در نتیجه در تناظر هر $B$ (عدد $n$ رقمی در مبنای دو) یک عدد صحیح $q$ بین 0 تا $2^n$ وجود دارد.
#
# چرا این گزاره صحیح است؟ زیرا می‌توانیم $B$ را به مبنای ده ببریم. اگر $B$ را به مبنای ده ببریم می‌تواند حداقل 0 و حداکثر $ 2^n - 1$ باشد.
#
#
# کافیست اعداد صحیح بین  $0$ و $2 ^ n$ را به مبنای دو ببریم تا هر یک بیانگر یک حالت جواب($X$) باشد.
#
# یا به عبارتی روند زیر را برای رسیدن به یک جواب $X$ طی کنیم:
# $$ q \ \ \ \rightarrow \ \ \ B \ \ \ \rightarrow \ \ \ X$$
#
# به طور مثال نمونه زیر برای $n=3$ یا همان زمانی است که $3$ کالا داریم:
# $$
# 0  \rightarrow \ \ \   000   \rightarrow \ \ \  \{0, 0, 0\} \\
# 1  \rightarrow \ \ \   001   \rightarrow \ \ \  \{0, 0, 1\} \\
# 2  \rightarrow \ \ \   010   \rightarrow \ \ \  \{0, 1, 0\} \\
# 3  \rightarrow \ \ \   011   \rightarrow \ \ \  \{0, 1, 1\} \\
# 4  \rightarrow \ \ \   100   \rightarrow \ \ \  \{1, 0, 0\} \\
# 5  \rightarrow \ \ \   101   \rightarrow \ \ \  \{1, 0, 1\} \\
# 6  \rightarrow \ \ \   110   \rightarrow \ \ \  \{1, 1, 0\} \\
# 7  \rightarrow \ \ \   111   \rightarrow \ \ \  \{1, 1, 1\}
# $$
# با توجه به این توضیحات، تابعی برای حل سوال با بررسی همه حالات می‌نویسیم:
#     </font>
# </div>

# %%
def do_bruteforce(n, k, V, W):
    # Do bruteforce
    
    # initialize answer
    max_total_value = 0
    result = []
    
    # check for i(q) in [0, 2^n)
    for i in range(2 ** n):
        X = []
        X_length = 0
        
        # base 10 to binary
        while i != 0:
            x = i % 2
            i //= 2
            X.append(x)
            X_length += 1
            
        X += [0] * (n - X_length)
        X.reverse()  ###  Extra Computation But make it more clear
        
        #print(X)  # view X 
        
        # Evaluate our answer(X)
        total_value = 0
        total_weight = 0
        
        for j in range(n):
            total_weight += W[j]*X[j]
            total_value += V[j]*X[j]
        
        # Check if we find better answer(X)
        if total_value > max_total_value and total_weight <= k:
            max_total_value = total_value
            result = X[:]
    
    return result

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
# حالا بیایید تا کد خود را به ازای همان ورودی $n=7$ بررسی کنیم:
#     </font>
# </div>

# %%
test_solver(7, do_bruteforce)

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
# می‌بینیم که بله! کد ما درست کار می‌کند! خروجی ما بهترین خروجی ممکن است که دارای ارزش 20 است.
# حالا بیایید تا $n$ را به ازای ورودی های بزرگتر مثل 19، 30 و 50 بررسی کنیم.
#     </font>
# </div>

# %%
test_solver(19, do_bruteforce)

# %%
test_solver(30, do_bruteforce)

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <p></p>
# کد ما به ازای $n$  برابر $30$ و مقادیر بزرگتر نمی‌تواند به خوبی فعالیت کند. هرچقدر منتظر هستیم، به ما جوابی برنمیگرداند!
#
# به نظر شما چرا این اتفاق می‌افتد؟
#
# اگر خیلی منتظر بوده‌اید بهتر است کلید مربعی را در نوار بالای صفحه فشار دهید:)
# <img src='images/stop-notebook.jpg' style="width:60%;height:60%;">
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="MODELLING" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             چقدر صبر کنیم؟!
#         </font>
#         <p></p>
# می‌دانیم هر $x_i$ که عضوی از $X$ است، $0$ یا $1$ می‌باشد. در نتیجه برای هر $x_i$ دو حالت وجود دارد. (بنا به اصل ضرب) تعداد $X$ های موجود برابر $2^n$ می‌باشد.
#
# اگر بررسی هر حالت را $1$ عملیات در نظر بگیریم، برنامه ما با انجام $2^n$ عملیات پاسخ را می‌یابد.
#
# زبان برنامه نویسی ++C می‌تواند حدود $ 10 ^ 8$ عملیات را در ثانیه انجام دهد. حال می‌خواهیم ببینیم به ازای $n = 50$ (تعداد کالای $50$) برنامه ما چقدر  طول می‌کشد تا اجرا شود.
#
# با انجام تقسیمی ساده می‌بینید که حدود $4$ ماه زمان می‌برد تا برنامه ما به جواب برسد:)
# این را در نظر بگیرید که برای عدد کوچکی مثل $50$ این اتفاق می‌افتد.
#
# نکته جالبی که وجود دارد این است که اگر این مقدار را برای $n = 100$ محاسبه کنیم متوجه می‌شویم که حدودا $10^{14}$ سال می‌کشد تا جواب درست یافت شود:)
#
# این مورد را که زبان برنامه‌نویسی ++C از پایتون سریع‌تر است نیز در نظر داشته باشید!)
#
#  حالا اگر مسئله را با ابعاد دنیای واقعی در نظر بگیریم که ورودی ها بسیار بزرگتر هستند چه اتفاقی می‌افتد؟
#
# ما نمی‌توانیم در این نقطه ادعا کنیم که مسئله را کاملا حل کرده ایم! مساله ما به ازای ورودی های کوچکی جواب می‌دهد. چه ایده‌ای برای ورودی های بزرگ‌تر دارید؟
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="MODELLING" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             تخمین پاسخ مناسب
#         </font>
#         <p></p>
# این‌که نمی‌توان همه یا بخش خوبی از جواب‌ها را بررسی کرد، ما را به روش های دیگری وا می‌دارد. همچنین روشی که این ویژگی را ندارد دارای قطعیت نیست، زیرا ممکن است با جابجا شدن یک کالا جواب بهتری کشف شود. درنتیجه ما نمی‌توانیم لزوما به دنبال بهترین جواب بگردیم. راه حلی که برای ما می‌ماند تخمین پاسخ مناسب است!
#
# جاهایی که ورودی ها بسیار بزرگ هستند، ما نمی‌توانیم همچین برخوردی با مساله داشته باشیم. این‌که ما جوابی داشته باشیم که ندانیم لزوما بهترین جواب است یا خیر، خیلی بهتر از این است که هیچ جوابی نداشته باشیم!
#
# حتی همین روش حریصانه نیز برای ما جوابی دارد، در نتیجه بهتر از راه حل قطعی‌ای است که به ما هیچ جوابی ندهد:)
#
# پس ما باید هدف خود را روی بهینه‌سازی قرار دهیم و تا جای ممکن جواب خود را بهتر و بهتر کنیم.
#
# می‌دانیم که ممکن است پاسخ بهتری نسبت به پاسخ ما وجود داشته باشد زیرا روش ما غیر قطعی است. اما در این روش غیر قطعی نیز باید تا حد امکان جواب خوبی را خروجی دهیم.
#
# دسته ای از الگوریتم ها وجود دارند که در آن، دقت قربانی سرعت می‌شود. وقتی که الگوریتم‌های کلاسیک از بدست آوردن جواب قطعی عاجزند، چاره‌ای جز روی آوردن به این روش‌ها نیست. الگوریتم‌های اکتشافی (heuristic) از این دسته الگوریتم ها هستند.
# در این الگوریتم‌ها تلاش ما بر بهتر و بهتر کردن وضعیت فعلیست.
#
# پس سعی ما از این به بعد بر تخمین خوب جواب مسئله است. ما به دنبال پاسخی هستیم که به اندازه کافی مناسب باشد.
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="MODELLING" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             آیا جواب ما مناسب است؟
#         </font>
#         <p></p>
#
# قبل‌تر گفتیم که ما باید به دنبال جواب مناسبی باشیم. اما مناسب به چه معناست؟ ما باید بتوانیم این عبارت را تعریف کنیم و بتوانیم میان چند جواب مناسب‌ترین را انتخاب کنیم. برای بررسی مناسب بودن یک پاسخ، باید به دنبال یک روند ارزیابی باشیم.
#
# ما باید تابع ارزیابی‌ای داشته باشیم که میزان خوب یا بد بودن جوابی که به‌دست آوردیم (کوله‌پشتی‌ای که یافتیم) را نشان دهد. در مساله‌های مختلف ما این‌کار را با تابع خطا (loss) یا تابع ارزش (value) تعریف می‌کنیم. اگر معیار ارزیابی ما ارزش باشد، هدف ما یافتن پاسخی است که مقدار ارزش آن بیشینه باشد. اما اگر معیار ما در مساله خطا باشد باید پاسخی را بیابیم که مقدار خطا برای آن کمینه است.
#
# مساله کوله‌پشتی ما با تابع ارزش سنجیده می‌شود. اما در مساله‌ای همچون $n$ وزیر($n$ وزیر را در صفحه شطرنج $n \times n$ که هم را تهدید نکنند.)، می‌توانیم تابعی همچون تابع خطا تعریف کنیم که بیانگر تعداد وزیر هایی است که هم را تهدید می‌کنند. هدف ما در این مساله، یافتن پاسخی است که تابع خطا برای آن کمینه باشد.
#
# البته برای این مساله تابع ارزش هم قابل دریافت است. احتمالا برایتان سوال باشد که چگونه؟
#
# می‌دانیم که برای ایجاد شرایط تهدید، به دو وزیر نیازمندیم. اگر به ازای هر دو وزیری که در صفحه انتخاب می‌کنیم، هر دو وزیر همدیگر را تهدید کنند، در این شرایط بیشینه مقدار برای تهدید وجود دارد. در نتیجه می‌توانیم بگوییم که بیشینه تهدید $\binom{n}{2}$ است.
#
# حال می‌توانیم تابع ارزش خود را این‌گونه تعریف کنیم:
# $$\text{value}(S) = \binom{n}{2} - \text{threats}$$
#
# در اینجا $\text{threats}$ تعداد کل تهدید‌ها در صفحه شطرنج(در پاسخ $S$) و $S$ نیز جوابی که ما یافتیم می‌باشد(یک شیوه چینش $n$ وزیر در صفحه شطرنج).
#
# می‌دانیم بیشینه مقدار تهدید ها $\binom{n}{2}$ است، در نتیجه مقدار این تابع همواره بزرگتر مساوی $0$ است. هر چه این تابع مقدار بزرگتری را به ما برگرداند، نشان کمتر بودن تهدید ها و مناسب تر بودن جواب است.
#
# دیدید که بسیار ساده توانستیم هر دو تابع ارزش و خطا را برای این مساله تعریف کنیم. انتخاب این‌که مساله را بر اساس کدام تابع حل کنیم، بر عهده ماست و به مدل سازی ما بستگی دارد. ما در مدل سازی کوله‌پشتی از تابع ارزش استفاده کردیم.
#
# تابع ارزش ما در این مساله کوله‌پشتی بدین گونه تعریف شد:
# $$ \text{value(X)}= \sum_{i=1}^{n}v_i \times x_i$$
# $$x_{i}\in \{0,1\}$$
#
# در اینجا $X$ یک جواب معتبر برای مساله ما می‌باشد.
#
# برای درک بهتر، تمرین زیر را حل کنید:)
#
# <b style="color:red;"> تمرین: </b>
#
# تابع خطا را برای مساله کوله‌پشتی تشکیل دهید و مساله را مجددا برای خود مدل‌سازی کنید.
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="OPTIMIZATION" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             بهینه‌سازی
#         </font>
#         <p></p>
# گفته بودیم که ما به دنبال مناسب‌تر کردن جواب خود هستیم. ما دوست داریم که به مناسب‌ترین جواب ممکن برسیم. می‌توانیم بهینه‌سازی را فرایند مناسب‌تر کردن پاسخ موجود تعریف کنیم.
#
# آیا در امر بهینه‌سازی ما باید لزوما به مناسب‌ترین جواب ممکن برسیم؟ خیر! در بحث بهینه‌سازی، هدف ما بهتر کردن پاسخ موجود است. ما می‌خواهیم پاسخ خود را مناسب‌تر کنیم. حال چه بهینه‌سازی ما پاسخی بسیار عالی برگرداند و چه پاسخی که میزان کمی از
# پاسخ اولیه ما بهتر است، امر بهینه‌سازی (بهتر کردن) را انجام داده است.
#
# بهتر کردن را همان مناسب‌تر کردن پاسخ خود می‌دانیم.
#
# برای تعریف مناسب بودن نیاز به تعریف تابع ارزیابی داریم. اگر تابع ارزیابی وجود نداشته باشد، ما نمی‌توانیم مفهوم مناسب‌تر بودن را تعریف کنیم.
#
# حال برای انجام امر بهینه‌سازی ما باید به دنبال پاسخ‌هایی باشیم که از پاسخ ما بهینه‌تر (بهتر) باشد. یکی از ساده ترین ایده‌هایی که وجود دارد، بررسی همه پاسخ‌ها است. اگر ما همه پاسخ‌ها را بررسی کنیم، می‌توانیم پاسخی بهتر از پاسخی که الان در دست داریم پیدا کنیم و به عنوان خروجی بهینه‌سازی خود ارائه دهیم.
#
# ولی هدف ما فرار از راه حل بررسی همه جواب‌ها بود! چه ایده دیگری برای بهینه‌سازی دارید؟ احتمالا به ذهنتان برسد که فضایی که دنبال پاسخ بهینه در آن هستیم را کوچک‌تر کنیم.
#
# برای تعریف این فضا چه ایده‌ای دارید؟
#     </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             همسایگی
#         </font>
#         <p></p>
# ایده مناسبی که برای محدود کردن فضای مسئله دارد، محدود کردن فضا به پاسخ فعلی است.
#
# بیایید تا مفهوم همسایگی را برای یک پاسخ $X$ تعریف کنیم. ‌این بیان شهودی می‌تواند شروع خوبی بر ماجرای همسایگی باشد.
# به پاسخ هایی که با پاسخ $X$ اختلاف کمی دارند، همسایگی پاسخ $X$ می‌گوییم.
# حالا می‌توانیم ادامه کار را راحت‌تر جلو برویم.
#
# ما باید فضای مساله را به فضای پاسخ های شبیه به $X$ محدود کنیم و در میان آن ها پاسخ بهتر را دریابیم.
#
# حالا باید شبیه را تعریف کنیم. پاسخ شبیه پاسخ $X$ باید چه ویژگی هایی داشته باشد؟ چه ایده‌هایی برای تعریف این مورد در مساله کوله‌پشتی دارید؟
#
# بیایید تا فضای مساله (پاسخ های مساله) را با شکلی غیر دقیق شبیه‌سازی کنیم.
#
# <img src='images/solution_space.jpg' style="width:50%;height:50%;">
#
# فرض کنید ما مسیری را رفته‌ایم و این‌که این مسیر به کمک چه راه حلی بوده برای ما اهمیتی ندارد. این مسیر می‌تواند یک ایده‌ی حریصانه‌‌ی ساده باشد یا می‌تواند یک الگوریتم بهینه‌سازی پیچیده‌ باشد.
# فی‌الحال چیزی که برای ما مهم است، بودن ما در این نقطه است.
# ما می‌توانیم از این نقطه به جهات مختلفی حرکت کنیم. حرکت به سمت هر جهت، جواب متفاوتی به ما می‌دهد. اگر ما یک قدم در هر جهت حرکت کنیم، به یک جواب بسیار شبیه به جواب فعلی خود می‌رسیم.
# حال ما باید تمام نقاط اطراف خود(نقاط در همسایگی راه حل فعلی)  را دریابیم و مناسب‌ترین را پیدا کنیم.
#
# حال چگونه می‌توانیم این نقاط را پیدا کنیم؟ ما باید قدم های خود را بر اساس تعدادی عملیات ریاضی تعریف کنیم.
# عملیات چیست؟ عملیات تابعی است که اگر پاسخ $X$ را به آن ورودی دهیم، پاسخ جدیدی به ما خروجی خواهد داد.
#
# فرض کنید عملیات $p$ را برای مساله کوله‌پشتی بدین نحو تعریف کنیم: در این عملیات مولفه $0$ ام $X$ یعنی $x_0$ معکوس می‌شود(اگر $0$ بود $1$ و اگر ‌$1$ بود، $0$ می‌شود.).
#
# برای نمونه اگر $X = \{0, 1, 0\}$ باشد، $p(x) = \{1, 1, 0\}$ خواهد شد.
# دیدیم که این تابع به ازای دریافت پاسخ $X$ یک پاسخ متفاوت را به ما برمی‌گرداند.
#
# تابع $p$ یکی از قدم های ما است. ما قدم‌های متعددی در این نقطه می‌توانیم تعریف کنیم. می‌توانیم دید خود را باز‌تر کنیم و انتخاب های بیشتری برای خود بسازیم. برای ساخت هر قدم نیاز به یک تابع است.
#
# می‌توانیم با مجموعه‌ای از توابع به نام $P$ که $P = \{p_1, p_2, \dots\}$ همسایگی های $X$ را بیابیم.
#
# می‌توانیم همسایگی های $X$ را به گونه زیر تعریف کنیم:
#
# $$\operatorname{N}(X) = \{ \operatorname{p}(X)\mid{\operatorname{p} \in P}\}$$
#
# حالا اگر ما $m$ تابع داشته باشیم باید تمام توابع $p_i$ را تعریف کنیم. می‌توانیم به جای مجموعه ای از توابع، تابع کلی $\operatorname{P}$ را به این نحو تعریف کنیم:
#
# $$\operatorname{P}(X, i) = \operatorname{p_i}(X)$$
#
# بیایید تا تمام توابع $p_i$ را به ازای $i$ برای مساله کوله‌پشتی تعریف کنیم. تابع $p_i$ پاسخ $X$ را به پاسخ جدیدی تبدیل می‌کند که در آن مولفه  $i$ ام $X$ یعنی $x_i$ معکوس می‌شود.
#
# حال کد تابع ($p_i$) را تکمیل کنید. تابع شما $X$ و $i$ را ورودی می‌گیرد و همسایه جدید را خروجی می‌دهد.
#     </font>
# </div>

# %%
def get_neighbour(X, i):
    # P(i, x) function
    return X

# %% [markdown]
# <p></p>
# <br />
# <div id="" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         <p></p>
# طبق گفته قبل می‌دانیم که مجموعه تمام همسایه ها معادل عبارت زیر است:
#
# $$\operatorname{N}(X) = \{ \operatorname{p}(X)\mid{\operatorname{p} \in P}\}$$
#
# حالا تابعی زیر را کامل کنید. این تابع $X$ را ورودی می‌گیرد و تمام همسایه های آن یعنی $\operatorname{N}(X) $ را خروجی می‌دهد.
#
# <b style="color:purple;"> راهنمایی: </b>
#
# دقت کنید که برای نوشتن این تابع، نیاز است تا از تابعی که سری قبل نوشتید استفاده کنید. تابع قبل به ازای $X$ و $i$ یک همسایه به ما می‌داد. شما باید تمام $i$ ها را از 0 تا $n$ برای این امر بررسی کنید و همه همسایه ها را خروجی دهید.
#     </font>
# </div>

# %%
def get_all_neighbours(X, i):
    # get all neighbours
    all_neighbours = []
    return all_neighbours
